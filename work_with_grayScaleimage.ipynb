# %% [markdown]
# <a href="https://colab.research.google.com/github/sedavasema/mohammad/blob/main/work_with_grayScaleimage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # تبدیل تصاویر به سطح خاکستری یا Grayscaling

# %%
# !wget https://raw.githubusercontent.com/sedavasema/one-shot-learning/main/mydataset/4.jpg
# Out:
# --2023-07-03 05:39:56--  https://raw.githubusercontent.com/sedavasema/one-shot-learning/main/mydataset/4.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32106 (31K) [image/jpeg]
# Saving to: ‘4.jpg’
#
# 4.jpg               100%[===================>]  31.35K  --.-KB/s    in 0.001s
#
# 2023-07-03 05:39:57 (27.4 MB/s) - ‘4.jpg’ saved [32106/32106]

# %%
from google.colab.patches import cv2_imshow
import cv2
img=cv2.imread('./4.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=260x360 at 0x7F4DE5B32A40>

# %%
gray_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=260x360 at 0x7F4DAE545C60>

# %% [markdown]
# # با پاس دادن صفر به ایمرد میتوان گفت از اول عکس را سیاه و سفید بخوان

# %%
gray_img=cv2.imread('./4.jpg',0)
print(gray_img.shape)
cv2_imshow(gray_img)
# Out:
# (360, 260)
# <PIL.Image.Image image mode=L size=260x360 at 0x7F4DAE5466B0>

# %% [markdown]
# نمایش تصاویر با متپلات لیب

# %%
import matplotlib.pyplot as plt
img=cv2.imread('./4.jpg',0)

# %% [markdown]
# # متپلات لیب ذاتا برای نمایش نمودار است و وقتی با آن تصویر نمایش میدیم اعداد را درصد وقوع در نظر میگیرد مثلا عدد بیشتر را سبز تر نشان بده و عدد کمتر را با سبز کمتر حال اگر میخواهیم کمتر یا بیشتر را با خاکستری بسنجد باید به آن بگوییم

# %%
plt.imshow(img)

# %%
plt.imshow(img, cmap='gray')

# %% [markdown]
# # به ابعاد تصویر رنگی و سطح خاکستری نگاهی بیندازیم

# %%
image=cv2.imread('./4.jpg')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=260x360 at 0x7F4DAACD7B50>

# %%
image=cv2.imread('./4.jpg')
print(image[150,70])
B,G,R=image[150,70]#tuple unpaking
print(B,G,R)
print(image.shape)
# Out:
# [38 50 74]
# 38 50 74
# (360, 260, 3)

# %% [markdown]
# # وقتی تصویر را تبدیل به گری اسکیل میکنید میانگین وزن دار سه کانال را حساب میکند
#
#
# ```
# # This is formatted as code
# ```
#
# round(0.2989*R+0.5870*G+0.1140*B)

# %%
gray_img=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
print(gray_img[150,70])
print('shape:',gray_img.shape)
# Out:
# 56
# shape: (360, 260)

# %% [markdown]
# میانگین گیری با فرمول بالا

# %%
round(0.2989*R+0.5870*G+0.1140*B)
# Out:
# 56

# %% [markdown]
# # تمرین: میخواهیم تصویر رنگی را خودمان گری اسکیل کنیم برای سادگی میانگین معمولی بگیرین نه وزن دار

# %%
newimage=image[:,:,0]//3+image[...,1]//3+image[...,2]//3
plt.imshow(newimage,cmap='gray')
